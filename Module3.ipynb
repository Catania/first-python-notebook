# %%
import pandas as pd

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
prop = props[props.prop_name == "PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES OF 2016), ALLEN. CAMPAIGN FINANCE: VOTER INSTRUCTION"]

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
pd.merge(prop, contribs, on="calaccess_committee_id")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 1    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 2    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 3    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 4    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 5    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 6    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 7    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 8    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 9    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 10   ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 11   ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# ...

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 561 entries, 0 to 560
# Data columns (total 20 columns):
# ocd_prop_id                     561 non-null object
# calaccess_prop_id               561 non-null int64
# ccdc_prop_id                    561 non-null int64
# prop_name                       561 non-null object
# ccdc_committee_id               561 non-null int64
# calaccess_committee_id          561 non-null int64
# committee_name_x                561 non-null object
# committee_position              561 non-null object
# committee_name_y                561 non-null object
# calaccess_filing_id             561 non-null int64
# date_received                   561 non-null object
# contributor_lastname            561 non-null object
# contributor_firstname           537 non-null object
# contributor_city                561 non-null object
# contributor_state               561 non-null object
# contributor_zip                 561 non-null object
# ...

# %%
merged.amount.sum()
# Out:
# 258546.60000000001

# %%
merged[merged.committee_position == "SUPPORT"].amount.sum()
# Out:
# 258546.60000000001

# %%
merged[merged.committee_position == "SUPPORT"]
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 1    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 2    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 3    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 4    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 5    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 6    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 7    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 8    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 9    ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 10   ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 11   ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# ...

# %%
support = merged[merged.committee_position == "SUPPORT"]

# %%
support.amount.sum()
# Out:
# 258546.60000000001

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 1.0

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %%
oppose.amount.sum()
# Out:
# 0

# %%
merged.sort_values("amount" , ascending = False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 213  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 212  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 237  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 217  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 234  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 215  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 130  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 236  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 241  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 246  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 251  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# 245  ocd-contest/fbffc731-c1a5-4fd8-b7ce-f0623a278ab5            1386783
# ...

# %%
oppose.sort_values("amount" , ascending = False)
# Out:
# Empty DataFrame
# Columns: [ocd_prop_id, calaccess_prop_id, ccdc_prop_id, prop_name, ccdc_committee_id, calaccess_committee_id, committee_name_x, committee_position, committee_name_y, calaccess_filing_id, date_received, contributor_lastname, contributor_firstname, contributor_city, contributor_state, contributor_zip, contributor_employer, contributor_occupation, contributor_is_self_employed, amount]
# Index: []

# %%
merged.groupby("committee_name_x")

# %%
merged.groupby("committee_name_x").amount.sum()
# Out:
# committee_name_x
# CALIFORNIA COMMON CAUSE -- YES ON 54 AND 59 (NONPROFIT 501(C)(4)                                                   50388.84
# MAKE THEM LISTEN - YES ON 59                                                                                        1012.81
# OVERTURN CITIZENS UNITED, YES ON 59                                                                                53457.33
# PROTEUS ACTION LEAGUE NON-PROFIT 501 (C)(4) ORGANIZATION, OPPOSING MEASURE 66 AND SUPPORTING MEASURES 54 AND 59    96790.12
# YES ON 59, CALIFORNIA CLEAN MONEY ACTION FUND TO OVERTURN CITIZENS UNITED (NON PROFIT 501(C)4)                     56897.50
# Name: amount, dtype: float64

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount" , ascending = False).head()
# Out:
#                                     committee_name_x    amount
# 3  PROTEUS ACTION LEAGUE NON-PROFIT 501 (C)(4) OR...  96790.12
# 4  YES ON 59, CALIFORNIA CLEAN MONEY ACTION FUND ...  56897.50
# 2                OVERTURN CITIZENS UNITED, YES ON 59  53457.33
# 0  CALIFORNIA COMMON CAUSE -- YES ON 54 AND 59 (N...  50388.84
# 1                       MAKE THEM LISTEN - YES ON 59   1012.81

# %%
merged.groupby(["contributor_lastname", ]).amount.sum().reset_index().sort_values("amount" , ascending = False).head()
# Out:
#                 contributor_lastname    amount
# 277  THE ATLANTIC ADVOCACY FUND INC.  60000.00
# 42           CALIFORNIA COMMON CAUSE  19098.84
# 69                             DOLBY  15000.00
# 290           VOQAL USA PHILANTHROPY  15000.00
# 215            PROTEUS ACTION LEAGUE  14000.00

# %%
merged.groupby(["contributor_lastname", "contributor_firstname", "committee_position"]).amount.sum().reset_index().sort_values("amount" , ascending = False).head()
# Out:
#     contributor_lastname contributor_firstname committee_position    amount
# 71                 DOLBY                DAGMAR            SUPPORT  15000.00
# 317                WOODS              LAURE L.            SUPPORT  12000.00
# 302               WATSON                  JOHN            SUPPORT  10300.00
# 201               MOSHER                 HOLLY            SUPPORT   5083.34
# 52              CLEMENTS                  JEFF            SUPPORT   5000.00

# %%
import pandas as pd
